# %% [markdown]
# <h2>Tugas Harian 2</h2>
#
# Dengan menggunakan data di bawah ini, plot kan data tersebut kemudian custom sehingga memiliki result seperti yang di harapkan :
#
# note : warna terdiri dari warna Hijau, kuning, Biru, dan Merah

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
cos = np.cos(x)
cos3 = np.cos(x)*3
sin = np.sin(x-90)
sin2 = np.sin(x)*2

fig, ax = plt.subplots()

plt.style.use('default')
ax.plot(x, cos, label='Cosx', color='red')
ax.plot(x, cos3, label='3 Cosx', linestyle='--', color='green')
ax.plot(x, sin, label='Sin(x-90)', linestyle='-.', color='blue')
ax.plot(x, sin2, marker='x', linestyle='', label='2 Sinx', color='yellow')
ax.legend(loc='center')
plt.xlabel('X-Axis Label')
plt.ylabel('Y-Axis Label')
plt.title('Grafik Cos Sin')
plt.show()

# %% [markdown]
# Expected Result :
#
# ![image.png](./Week_3_Tugas_Harian_2/image-4.png)
